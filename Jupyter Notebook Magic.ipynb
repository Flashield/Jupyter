# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %ls -al
# Out:
# total 120
# drwxrwxr-x 12 zhuangbin zhuangbin  4096 Aug 10 11:03  ./
# drwxrwxr-x 11 zhuangbin zhuangbin  4096 Aug  8 22:10  ../
# -rw-rw-r--  1 zhuangbin zhuangbin 20945 Mar 15 15:13  app.rsa.min.js
# -rw-r--r--  1 zhuangbin users      1678 Sep  9  2018  Copy.txt
# drwxrwxr-x  3 zhuangbin zhuangbin  4096 Jul 22 14:39  Coursera/
# drwxrwxr-x 10 zhuangbin zhuangbin  4096 Aug  8 23:40  CTF/
# drwxrwxr-x  3 zhuangbin zhuangbin  4096 Apr 29 15:59  DataMining/
# -rw-r--r--  1 zhuangbin users      1692 Aug 18  2018  HttpServer.ipynb
# drwxrwxr-x  2 zhuangbin zhuangbin  4096 Mar 15 14:52  .ipynb_checkpoints/
# drwxrwxr-x 15 zhuangbin zhuangbin  4096 Jul 26 09:48 'My Project'/
# drwxr-xr-x  5 zhuangbin users      4096 Aug  8 22:25  Python3/
# drwxrwxr-x  3 zhuangbin zhuangbin  4096 Sep  5  2018  TensorFlow/
# drwxrwxr-x  4 zhuangbin zhuangbin  4096 Aug 10 10:06 'TensorFlow 十课'/
# drwxrwxr-x  2 zhuangbin zhuangbin  4096 Jul 22 14:34 'TensorFlow 实战Google深度学习框架'/
# ...

# %%
# %%sh
# #查找文件内的关键字
# grep -ri lxml .
# Out:
# ./My Project/Spider/CheckProxy-Copy1.ipynb:    "import lxml\n",
# ./My Project/Spider/CheckProxy-Copy1.ipynb:    "from lxml import etree\n",
# ./My Project/Spider/CheckProxy-Copy1.ipynb:    "    req_xml = lxml.etree.HTML(request_read.decode(encoding='UTF8',errors='ignore'))\n",
# ./My Project/Spider/CheckProxy-Copy1.ipynb:    "    req_xml = lxml.etree.HTML(request_read.decode(encoding='UTF8',errors='ignore'))\n",
# ./My Project/Spider/CheckProxy-Copy1.ipynb:    "            req_xml = lxml.etree.HTML(request_read.decode(encoding='UTF8',errors='ignore'))\n",
# ./My Project/Spider/CheckProxy-Copy1.ipynb:    "            parse_xml = lxml.etree.HTML(searchObj.group(1))\n",
# ./My Project/Spider/CheckProxy-Copy1.ipynb:    "            req_xml = lxml.etree.HTML(request_read.decode(encoding='UTF8',errors='ignore'))\n",
# ./My Project/Spider/CheckProxy-Copy1.ipynb:    "    req_xml = lxml.etree.HTML(request_read.decode(encoding='UTF8',errors='ignore'))\n",
# ...
