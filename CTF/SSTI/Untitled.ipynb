# %%
cnt = 0
for item in "".__class__.__mro__[1].__subclasses__():
    try:
        cnt2 = 0
        for i in item.__init__.__globals__:
            print(cnt,item,i,cnt2)
            if 'eval' in item.__init__.__globals__[i]:
                print(cnt,item,cnt2,i)
            cnt2 += 1
        cnt += 1
    except Exception as ex:
        print(ex)
        print("error",cnt,item,i)
        cnt += 1
        continue
# Out:
# 'wrapper_descriptor' object has no attribute '__globals__'
# error 0 <class 'type'> __loader__
# 'wrapper_descriptor' object has no attribute '__globals__'
# error 1 <class 'weakref'> __loader__
# 'wrapper_descriptor' object has no attribute '__globals__'
# error 2 <class 'weakcallableproxy'> __loader__
# 'wrapper_descriptor' object has no attribute '__globals__'
# error 3 <class 'weakproxy'> __loader__
# 'wrapper_descriptor' object has no attribute '__globals__'
# error 4 <class 'int'> __loader__
# 'wrapper_descriptor' object has no attribute '__globals__'
# error 5 <class 'bytearray'> __loader__
# 'wrapper_descriptor' object has no attribute '__globals__'
# error 6 <class 'bytes'> __loader__
# 'wrapper_descriptor' object has no attribute '__globals__'
# error 7 <class 'list'> __loader__
# 'wrapper_descriptor' object has no attribute '__globals__'
# error 8 <class 'NoneType'> __loader__
# 'wrapper_descriptor' object has no attribute '__globals__'
# ...

# %%
print("".__class__.__mro__[1].__subclasses__()[117].__init__.__globals__)
# Out:
# {'__name__': 'os', '__doc__': "OS routines for NT or Posix depending on what system we're on.\n\nThis exports:\n  - all functions from posix or nt, e.g. unlink, stat, etc.\n  - os.path is either posixpath or ntpath\n  - os.name is either 'posix' or 'nt'\n  - os.curdir is a string representing the current directory (always '.')\n  - os.pardir is a string representing the parent directory (always '..')\n  - os.sep is the (or a most common) pathname separator ('/' or '\\\\')\n  - os.extsep is the extension separator (always '.')\n  - os.altsep is the alternate pathname separator (None or '/')\n  - os.pathsep is the component separator used in $PATH etc\n  - os.linesep is the line separator in text files ('\\r' or '\\n' or '\\r\\n')\n  - os.defpath is the default search path for executables\n  - os.devnull is the file path of the null device ('/dev/null', etc.)\n\nPrograms that import and use 'os' stand a better chance of being\nportable between different platforms.  Of course, they must
# ...

# %%
print("".__class__.__mro__[1].__subclasses__()[121].__init__.__globals__['__builtins__']['eval']('7+8'))
# Out:
# 15

# %%
"".__class__.__mro__[1].__subclasses__()[121]
# Out:
# types.DynamicClassAttribute
