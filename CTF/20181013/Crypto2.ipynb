# %%
import hashlib
hash = hashlib.sha256()
for i in range(10000000000):
    a=str(i)
    c=a.encode('utf-8')
    hash.update(c)
    b=hash.hexdigest()
    if i % 1000000 ==0:
        print(i,a,b,b[:5])
    if b[:5] == b'35fb8':
        print(b,a)
# Out:
# 0 0 5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91b46729d73a27fb57e9 5fece
# 1000000 1000000 4d21ff2ec2c8304fa1c3dfb833d314a6c7a199b01c52d8ef36b518f7cc0b3551 4d21f
# 2000000 2000000 cdb0b3d2cba1f0650c4b77d328b60c50ecfd6bd9a71dbd00664c55fbdadc2bfc cdb0b
# 3000000 3000000 a7fe1978ac7c143359c50bed2756f3c20f6d17b381d75471a39890b21addc7fe a7fe1
# 4000000 4000000 bf0a623ade4b87846eef2e1efce771ac771e34e95501a48c558215c9e8daacdb bf0a6
# 5000000 5000000 b653b7afc0ba9b21b5648b8dd74b79220cea243759f023eada26381579baefa8 b653b
# 6000000 6000000 b6bc7c706916b23cd7c247d673cf9ae35256b79236916e6059d2751fff59c821 b6bc7
# 7000000 7000000 0db1355d71c52061961b54c6e94b55561ec7ed7e1fd53546574a4c2e0cf33904 0db13
# 8000000 8000000 79b6dd7c38e7d640eb5f9cf5aa0cd9452968e527cf8ec4af2360620ed8b79c0b 79b6d
# 9000000 9000000 fb7c13c57754400f0275d4c7a0915a74cd8456a9be27bbf8fd0a9507cbb588d2 fb7c1
# 10000000 10000000 7229b1f4b8a22139964871f133e8bbb8724c93536179ebb9ee5157f1b3eca3cc 7229b
# ...
